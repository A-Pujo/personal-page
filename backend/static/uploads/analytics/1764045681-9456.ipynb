# %%
import numpy as np
import pandas as pd
import plotly.express as px
import altair as alt
import statsmodels.api as sm
from statsmodels.tsa.api import VAR, SimpleExpSmoothing, ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller, grangercausalitytests
from statsmodels.tsa.ardl import ARDL
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# # Data

# %%
export_data = pd.read_csv('export2003-2024.csv', sep=';')
print('in USD')
export_data
# Out:
# in USD
#        reporter  com_label                                          commodity  \
# 0     Indonesia          0                                 [01] Animals; live
# 1     Indonesia          0                    [02] Meat and edible meat offal
# 2     Indonesia          0  [03] Fish and crustaceans, molluscs and other ...
# 3     Indonesia          0  [04] Dairy produce; birds' eggs; natural honey...
# 4     Indonesia          0  [05] Animal originated products; not elsewhere...
# ...         ...        ...                                                ...
# 2129  Indonesia          9  [94] Furniture; bedding, mattresses, mattress ...
# 2130  Indonesia          9  [95] Toys, games and sports requisites; parts ...
# 2131  Indonesia          9           [96] Miscellaneous manufactured articles
# 2132  Indonesia          9  [97] Works of art; collectors' pieces and anti...
# 2133  Indonesia          9                                [99] Other products
#
#       year        export      import
# 0     2003  2.511837e+07    82754595
# 1     2003  2.177500e+07    44884944
# 2     2003  1.437417e+09    30132383
# 3     2003  1.082529e+08   277225879
# 4     2003  4.109344e+06     6504851
# ...    ...           ...         ...
# 2129  2024  2.427474e+09  1770940291
# 2130  2024  7.664741e+08   585605581
# 2131  2024  3.481782e+08   753185077
# 2132  2024  6.972042e+06    28392968
# 2133  2024  1.974912e+07  1168642295
#
# [2134 rows x 6 columns]

# %%
price_index_data = pd.read_csv('whoprice2003-2024.csv', sep=';')
price_index_data.tail()
# Out:
#     year  who_com_prices  energy_index  non_energy_index  precious_metal_index
# 17  2020           63.07         52.68             84.12                133.54
# 18  2021          100.90         95.38            112.09                140.17
# 19  2022          142.52        152.57            122.14                136.80
# 20  2023          108.04        106.95            110.24                147.34
# 21  2024          105.14        101.52            112.47                180.17

# %%
gdp_data = pd.read_csv('gdp2003-2024.csv', sep=';')
print('in IDR')
gdp_data.tail()
# Out:
# in IDR
#     year            export            import                gdp
# 17  2020  2676513530000000  2415495970000000  15443353200000000
# 18  2021  3635835410000000  3189626450000000  16976751400000000
# 19  2022  4799815440000000  4106085660000000  19588089900000000
# 20  2023  4543377780000000  4088446950000000  20892376700000000
# 21  2024  4911155650000000  4513987410000000  22138964000000000

# %% [markdown]
# # Export-Import Analysis

# %%
export_data['trade_balance'] = export_data['export'] - export_data['import']
# export_data['export_p'] = export_data['export'] / export_data['export'].sum() * 100
# export_data['import_p'] = export_data['import'] / export_data['export'].sum() * 100
export_data['com_label_name'] = export_data['com_label'].map({
    0: 'Food and animals',
    1: 'Beverages and cigarettes',
    2: 'Raw materials, edible, except fuels',
    3: 'Minerals, fuels and other',
    4: 'Animal & vegetable oils and fats',
    5: 'Chemicals and other products',
    6: 'Basic manufactures',
    7: 'Machinery, transport, equipment',
    8: 'Other manufactured goods',
    9: 'Other unclassifiable goods'
})
export_data.tail()
# Out:
#        reporter  com_label                                          commodity  \
# 2129  Indonesia          9  [94] Furniture; bedding, mattresses, mattress ...
# 2130  Indonesia          9  [95] Toys, games and sports requisites; parts ...
# 2131  Indonesia          9           [96] Miscellaneous manufactured articles
# 2132  Indonesia          9  [97] Works of art; collectors' pieces and anti...
# 2133  Indonesia          9                                [99] Other products
#
#       year        export      import  trade_balance  \
# 2129  2024  2.427474e+09  1770940291   6.565340e+08
# 2130  2024  7.664741e+08   585605581   1.808685e+08
# 2131  2024  3.481782e+08   753185077  -4.050069e+08
# 2132  2024  6.972042e+06    28392968  -2.142093e+07
# 2133  2024  1.974912e+07  1168642295  -1.148893e+09
#
#                   com_label_name
# 2129  Other unclassifiable goods
# 2130  Other unclassifiable goods
# 2131  Other unclassifiable goods
# 2132  Other unclassifiable goods
# 2133  Other unclassifiable goods

# %% [markdown]
# ## Commodities Traded

# %% [markdown]
# This is summation of export and import data for HS-1 Commodity for 2003 - 2024

# %%
overall_export_data = export_data.groupby('com_label_name')[['export', 'import']].sum().sort_values('import', ascending=False)
overall_export_data['export_share'] = overall_export_data['export'] / overall_export_data['export'].sum()
overall_export_data['import_share'] = overall_export_data['import'] / overall_export_data['import'].sum()
overall_export_data = overall_export_data.sort_values(by='export_share', ascending=False)
overall_export_data
# Out:
#                                            export         import  \
# com_label_name
# Raw materials, edible, except fuels  1.159074e+12   893961893139
# Other manufactured goods             5.017360e+11  1012788573604
# Beverages and cigarettes             4.783941e+11   166091345919
# Machinery, transport, equipment      3.728929e+11   332263771060
# Animal & vegetable oils and fats     3.652671e+11   120239587328
# Basic manufactures                   2.609218e+11    60965209120
# Minerals, fuels and other            1.830889e+11   303220197182
# Food and animals                     1.171328e+11    84882481572
# Other unclassifiable goods           9.236401e+10   108226217796
# Chemicals and other products         8.796179e+10   111362679792
#
#                                      export_share  import_share
# com_label_name
# Raw materials, edible, except fuels      0.320289      0.279888
# Other manufactured goods                 0.138646      0.317091
# Beverages and cigarettes                 0.132196      0.052001
# Machinery, transport, equipment          0.103042      0.104027
# Animal & vegetable oils and fats         0.100935      0.037645
# Basic manufactures                       0.072101      0.019087
# Minerals, fuels and other                0.050593      0.094934
# Food and animals                         0.032368      0.026576
# Other unclassifiable goods               0.025523      0.033884
# Chemicals and other products             0.024307      0.034866

# %%
fig = px.treemap(export_data, path=['com_label_name', 'commodity'], values="export", color='com_label_name', title='Overall Export 2003-2024 Treemap by Commodities')
fig.update_layout(margin = dict(t=50, l=0, r=0, b=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fcf237f-a9aa-4e34-a803-56409aac74e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fcf237f-a9aa-4e34-a803-56409aac74e6")) {                    Plotly.newPlot(                        "2fcf237f-a9aa-4e34-a803-56409aac74e6",                        [{"branchvalues":"total","customdata":[["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Raw materials, edible, except fuels"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Other unclassifiable goods"],["Food and animals"],["Other manufactured goods"],["Minerals, fuels and other"],["Basic manufactures"],["Machinery, transport, equipment"],["Food and animals"],["Chemicals and other products"],["Beverages and cigarettes"],["Animal & vegetable oils and fats"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ee ...

# %%
export_data[export_data['com_label_name']=='Raw materials, edible, except fuels'].groupby(['year', 'com_label_name'])[['export']].sum()
# Out:
#                                                 export
# year com_label_name
# 2003 Raw materials, edible, except fuels  1.982590e+10
# 2004 Raw materials, edible, except fuels  2.310076e+10
# 2005 Raw materials, edible, except fuels  3.012682e+10
# 2006 Raw materials, edible, except fuels  3.612965e+10
# 2007 Raw materials, edible, except fuels  3.205688e+10
# 2008 Raw materials, edible, except fuels  4.847431e+10
# 2009 Raw materials, edible, except fuels  4.238881e+10
# 2010 Raw materials, edible, except fuels  5.989589e+10
# 2011 Raw materials, edible, except fuels  8.300821e+10
# 2012 Raw materials, edible, except fuels  7.444809e+10
# 2013 Raw materials, edible, except fuels  7.005533e+10
# 2014 Raw materials, edible, except fuels  5.973249e+10
# 2015 Raw materials, edible, except fuels  4.364777e+10
# 2016 Raw materials, edible, except fuels  3.754175e+10
# 2017 Raw materials, edible, except fuels  4.804160e+10
# 2018 Raw materials, edible, except fuels  5.512583e+10
# 2019 Raw materials, edible, except fuels  4.515178e+10
# 2020 Raw materials, edible, except fuels  3.624410e+10
# 2021 Raw materials, edible, except fuels  6.195206e+10
# 2022 Raw materials, edible, except fuels  9.490550e+10
# 2023 Raw materials, edible, except fuels  8.039608e+10
# 2024 Raw materials, edible, except fuels  7.682443e+10

# %%
fig = px.treemap(export_data, path=['com_label_name', 'commodity'], values="import", color='com_label_name', title='Overall Import 2003-2024 Treemap by Commodities')
fig.update_layout(margin = dict(t=50, l=0, r=0, b=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="84939376-3f79-44e4-923b-c5ae0179ab15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84939376-3f79-44e4-923b-c5ae0179ab15")) {                    Plotly.newPlot(                        "84939376-3f79-44e4-923b-c5ae0179ab15",                        [{"branchvalues":"total","customdata":[["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Animal & vegetable oils and fats"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Basic manufactures"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Raw materials, edible, except fuels"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Beverages and cigarettes"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Chemicals and other products"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Food and animals"],["Other unclassifiable goods"],["Food and animals"],["Other manufactured goods"],["Minerals, fuels and other"],["Basic manufactures"],["Machinery, transport, equipment"],["Food and animals"],["Chemicals and other products"],["Beverages and cigarettes"],["Animal & vegetable oils and fats"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Machinery, transport, equipment"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Minerals, fuels and other"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other manufactured goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Other unclassifiable goods"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"],["Raw materials, edible, except fuels"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ei ...

# %%
export_data[export_data['com_label_name']=='Other manufactured goods'].groupby(['year', 'com_label_name'])[['import']].sum()
# Out:
#                                     import
# year com_label_name
# 2003 Other manufactured goods   8758537129
# 2004 Other manufactured goods  12451626729
# 2005 Other manufactured goods  15622205511
# 2006 Other manufactured goods  15825144084
# 2007 Other manufactured goods  15698083274
# 2008 Other manufactured goods  43652582114
# 2009 Other manufactured goods  36544316349
# 2010 Other manufactured goods  47896166933
# 2011 Other manufactured goods  57285388436
# 2012 Other manufactured goods  64956239763
# 2013 Other manufactured goods  57889031101
# 2014 Other manufactured goods  52508064256
# 2015 Other manufactured goods  46444237569
# 2016 Other manufactured goods  44872824856
# 2017 Other manufactured goods  50268646052
# 2018 Other manufactured goods  60955503184
# 2019 Other manufactured goods  57256874024
# 2020 Other manufactured goods  48109970469
# 2021 Other manufactured goods  58276233944
# 2022 Other manufactured goods  71051949951
# 2023 Other manufactured goods  72440444222
# 2024 Other manufactured goods  74024503654

# %%
export_grouped = export_data.groupby(['year', 'com_label_name'], as_index=False)['export'].sum()

fig = px.line(export_grouped,
              x='year',
              y='export',
              color='com_label_name',
              markers=True,  # Add markers for clarity
              title='Yearly Export Value by HS-1 Digit',
              labels={'export': 'Total Export Value', 'year': 'Year', 'com_label_name': 'Commodity'},
              template='plotly_white')  # Clean background style
fig.update_xaxes(tickmode='linear')
fig.update_layout(width=1100, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eee804d0-9cf3-44d3-bccd-951a286b2657" class="plotly-graph-div" style="height:400px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eee804d0-9cf3-44d3-bccd-951a286b2657")) {                    Plotly.newPlot(                        "eee804d0-9cf3-44d3-bccd-951a286b2657",                        [{"hovertemplate":"Commodity=Animal & vegetable oils and fats\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Export Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Animal & vegetable oils and fats","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Animal & vegetable oils and fats","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[8393985896.0,9391788986.0,10268787475.0,13241295432.0,14248209573.0,16150106387.0,11868302776.0,18432808959.0,23985647325.0,19986557649.0,19233526836.0,17205103911.0,15761304931.47,15076981593.76,18604586881.65,18736171583.06,17952019810.3,16982060103.57,20842487774.09,21074468438.77,18764505641.34,19066368796.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Basic manufactures\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Export Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic manufactures","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Basic manufactures","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5805296383.0,6389602659.0,7095766453.0,7988404989.0,8181224882.0,8794912685.0,8211976721.0,10024973066.0,12192840731.0,12004189448.0,12543426194.0,12787014419.0,13075375955.91,13096086776.04,14135736418.53,14967745112.96,13850602689.31,13082940849.79,16040903339.939999,18585065038.5,15564434399.0,16503294699.630001],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Beverages and cigarettes\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Export Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages and cigarettes","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Beverages and cigarettes","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4075380942.0,5662409227.0,6392339041.0,7763389417.0,12135041884.0,18183961530.0,14912295987.0,19472658196.0,24970135769.0,24388736939.0,22718860826.0,25052102271.0,22401594197.299995,21976111881.24,26794074060.52,24908442400.79,22147050771.8,25606347132.69,38637674671.65,41383078856.95,34534507896.99,34277934468.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Chemicals and other products\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Export Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chemicals and other products","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Chemicals and other products","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2847898389.0,3075567112.0,3423371550.0,3600086612.0,3853283534.0,3833266666.0,3345537548.0,4415118680.0,5198519036.0,4784720926.0,4843783949.0,4941080082.0,4591182740.73,4283235055.41,4284068308.48,4322456045.34,4301513762.49,3131554370.75,4233862170.75,3948344658.4900002,3364956378.7000003,3338380071.95],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Food and animals\u003cbr\u003eYear=%{x}\u ...

# %%
import_grouped = export_data.groupby(['year', 'com_label_name'], as_index=False)['import'].sum()

fig = px.line(import_grouped,
              x='year',
              y='import',
              color='com_label_name',
              markers=True,  # Add markers for clarity
              title='Yearly Import Value by HS-1 Digit',
              labels={'import': 'Total Import Value', 'year': 'Year', 'com_label_name': 'Commodity'},
              template='plotly_white')  # Clean background style
fig.update_xaxes(tickmode='linear')
fig.update_layout(width=1100, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5676634-5aac-4a56-8211-4b1b89413f77" class="plotly-graph-div" style="height:400px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5676634-5aac-4a56-8211-4b1b89413f77")) {                    Plotly.newPlot(                        "b5676634-5aac-4a56-8211-4b1b89413f77",                        [{"hovertemplate":"Commodity=Animal & vegetable oils and fats\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Import Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Animal & vegetable oils and fats","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Animal & vegetable oils and fats","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1581054595,2042242996,2208449348,2437775531,3293692975,4699496403,3550137723,5220076938,6656036463,6659253780,6464404286,6339268447,5389762790,5492077588,6464855135,7262208340,6900569692,5455006492,7589748625,8558142966,7589541623,8385784592],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Basic manufactures\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Import Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic manufactures","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Basic manufactures","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[305480712,391989798,408336071,461616009,500950837,1328895957,1167528595,2006382132,2582830037,2920163856,2997455107,3056925877,2998359763,3075468940,3610004312,4520012769,4671356940,3996148775,5039970512,5393742303,4642662690,4888927128],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Beverages and cigarettes\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Import Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages and cigarettes","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Beverages and cigarettes","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2145332455,2237212788,2342188115,2774374125,6507718864,4381646204,3801254592,5643279977,9488539529,8439400950,8299607899,8129881008,7274338025,8133296214,8379646952,9346142541,8481391774,8488238035,10790732404,12405730155,13407959183,15193434130],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Chemicals and other products\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Import Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chemicals and other products","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Chemicals and other products","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1434800248,1607158225,1469461875,1555201045,1600367583,4119609241,3280964567,4870162074,6860477996,6401078743,6592287096,6705177435,6148000307,6341344865,6774895163,7516083850,6765873058,4867001395,6469587494,7349386187,6129272855,6504488490],"yaxis":"y","type":"scatter"},{"hovertemplate":"Commodity=Food and animals\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Import Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Food and animals","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Food and animals","orientation":"v","showlegend":true,"x":[2003,2004,2005,20 ...

# %%
yearly_export_data = export_data.groupby('year')[['export', 'import', 'trade_balance']].sum()
yearly_export_data = yearly_export_data.reset_index()
yearly_export_data['export_growth'] = yearly_export_data['export'].pct_change() * 100
yearly_export_data['import_growth'] = yearly_export_data['import'].pct_change() * 100
yearly_export_data
# Out:
#     year        export        import  trade_balance  export_growth  \
# 0   2003  6.105825e+10   32550690611   2.850756e+10            NaN
# 1   2004  7.158461e+10   46524531358   2.506008e+10      17.239869
# 2   2005  8.565995e+10   57700882616   2.795907e+10      19.662528
# 3   2006  1.007986e+11   61065465536   3.973316e+10      17.672986
# 4   2007  1.141009e+11   74473430118   3.962746e+10      13.196873
# 5   2008  1.370204e+11  129197306224   7.823118e+09      20.087077
# 6   2009  1.165100e+11   96829162576   1.968083e+10     -14.968887
# 7   2010  1.577791e+11  135663284048   2.211582e+10      35.421092
# 8   2011  2.034966e+11  177435555736   2.606107e+10      28.975651
# 9   2012  1.900318e+11  191689471527  -1.657626e+09      -6.616710
# 10  2013  1.825518e+11  186628669880  -4.076871e+09      -3.936207
# 11  2014  1.759800e+11  178178816605  -2.198830e+09      -3.599971
# 12  2015  1.502823e+11  142694804223   7.587453e+09     -14.602644
# 13  2016  1.451862e+11  135652816501   9.533395e+09      -3.390983
# 14  2017  1.688282e+11  156985563722   1.184261e+10      16.283891
# 15  2018  1.800127e+11  188711350191  -8.698676e+09       6.624782
# 16  2019  1.676830e+11  171275736997  -3.592741e+09      -6.849339
# 17  2020  1.631918e+11  141568794630   2.162304e+10      -2.678362
# 18  2021  2.316095e+11  196189979075   3.541950e+10      41.924671
# 19  2022  2.919043e+11  237447056598   5.445724e+10      26.032967
# 20  2023  2.588575e+11  221886223535   3.697125e+10     -11.321116
# 21  2024  2.647059e+11  233652364205   3.105357e+10       2.259336
#
#     import_growth
# 0             NaN
# 1       42.929475
# 2       24.022491
# 3        5.831077
# 4       21.956706
# 5       73.481074
# 6      -25.053265
# 7       40.105812
# 8       30.791140
# 9        8.033292
# 10      -2.640104
# 11      -4.527629
# 12     -19.914832
# 13      -4.934999
# 14      15.725989
# 15      20.209366
# 16      -9.239303
# 17     -17.344513
# 18      38.582786
# 19      21.029146
# 20      -6.553391
# 21       5.302781

# %%
print('in Trillion USD')
(yearly_export_data[['export', 'import', 'trade_balance']]/1_000_000_000_000).agg(['sum', 'mean'])
# Out:
# in Trillion USD
#         export    import  trade_balance
# sum   3.618833  3.194002       0.424831
# mean  0.164492  0.145182       0.019311

# %% [markdown]
# ### HS-2 Share

# %%
commodity_export_per_year = pd.merge(yearly_export_data.rename(columns={'export': 'total_export', 'import': 'total_import'}), export_data, on='year')
commodity_export_per_year['export_share'] = commodity_export_per_year['export']/commodity_export_per_year['total_export']
commodity_export_per_year['import_share'] = commodity_export_per_year['import']/commodity_export_per_year['total_import']
commodity_export_per_year = commodity_export_per_year.drop(['trade_balance_x', 'trade_balance_y', 'export_growth', 'import_growth', 'reporter', 'total_export', 'total_import'], axis=1)

# %% [markdown]
# **Export**

# %%
commodity_export_share_per_year = commodity_export_per_year.sort_values(by=['year', 'export_share'], ascending=[True, False]).drop(['import_share', 'import'], axis=1)
commodity_export_share_per_year
# Out:
#       year  com_label                                          commodity  \
# 26    2003          2  [27] Mineral fuels, mineral oils and products ...
# 83    2003          8  [85] Electrical machinery and equipment and pa...
# 43    2003          4      [44] Wood and articles of wood; wood charcoal
# 14    2003          1  [15] Animal or vegetable fats and oils and the...
# 82    2003          8  [84] Nuclear reactors, boilers, machinery and ...
# ...    ...        ...                                                ...
# 2102  2024          6  [66] Umbrellas, sun umbrellas, walking-sticks,...
# 2079  2024          4  [43] Furskins and artificial fur; manufactures...
# 2087  2024          5  [51] Wool, fine or coarse animal hair; horseha...
# 2081  2024          4                     [45] Cork and articles of cork
# 2086  2024          5                                          [50] Silk
#
#             export                       com_label_name  export_share
# 26    1.571298e+10  Raw materials, edible, except fuels  2.573441e-01
# 83    6.118953e+09             Other manufactured goods  1.002150e-01
# 43    3.180501e+09     Animal & vegetable oils and fats  5.208961e-02
# 14    3.003362e+09             Beverages and cigarettes  4.918847e-02
# 82    2.787126e+09             Other manufactured goods  4.564701e-02
# ...            ...                                  ...           ...
# 2102  1.988018e+06                   Basic manufactures  7.510289e-06
# 2079  7.102266e+05     Animal & vegetable oils and fats  2.683078e-06
# 2087  4.672230e+05         Chemicals and other products  1.765064e-06
# 2081  2.035437e+05     Animal & vegetable oils and fats  7.689426e-07
# 2086  1.072983e+05         Chemicals and other products  4.053492e-07
#
# [2134 rows x 6 columns]

# %%
commodity_export_share_pivot_table = commodity_export_share_per_year.pivot_table(index='commodity', columns='year', values='export_share')
commodity_export_share_pivot_table['avg_share'] = commodity_export_share_pivot_table.mean(axis=1)
commodity_export_share_pivot_table = commodity_export_share_pivot_table.sort_values(by='avg_share', ascending=False)
commodity_export_share_pivot_table.to_csv('awikwik.csv', sep='|')
print("\nSorted and Formatted Pivot Table (Export Share as Percentages, Max Highlighted)")
display(commodity_export_share_pivot_table.style.format("{:.2%}").highlight_max(axis=0, color='#ffffb3'))
# Out:
# Sorted and Formatted Pivot Table (Export Share as Percentages, Max Highlighted)
# <style type="text/css">
# #T_34397_row0_col0, #T_34397_row0_col1, #T_34397_row0_col2, #T_34397_row0_col3, #T_34397_row0_col4, #T_34397_row0_col5, #T_34397_row0_col6, #T_34397_row0_col7, #T_34397_row0_col8, #T_34397_row0_col9, #T_34397_row0_col10, #T_34397_row0_col11, #T_34397_row0_col12, #T_34397_row0_col13, #T_34397_row0_col14, #T_34397_row0_col15, #T_34397_row0_col16, #T_34397_row0_col17, #T_34397_row0_col18, #T_34397_row0_col19, #T_34397_row0_col20, #T_34397_row0_col21, #T_34397_row0_col22 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_34397" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_34397_level0_col0" class="col_heading level0 col0" >2003</th>
#       <th id="T_34397_level0_col1" class="col_heading level0 col1" >2004</th>
#       <th id="T_34397_level0_col2" class="col_heading level0 col2" >2005</th>
#       <th id="T_34397_level0_col3" class="col_heading level0 col3" >2006</th>
#       <th id="T_34397_level0_col4" class="col_heading level0 col4" >2007</th>
#       <th id="T_34397_level0_col5" class="col_heading level0 col5" >2008</th>
#       <th id="T_34397_level0_col6" class="col_heading level0 col6" >2009</th>
#       <th id="T_34397_level0_col7" class="col_heading level0 col7" >2010</th>
#       <th id="T_34397_level0_col8" class="col_heading level0 col8" >2011</th>
#       <th id="T_34397_level0_col9" class="col_heading level0 col9" >2012</th>
#       <th id="T_34397_level0_col10" class="col_heading level0 col10" >2013</th>
#       <th id="T_34397_level0_col11" class="col_heading level0 col11" >2014</th>
#       <th id="T_34397_level0_col12" class="col_heading level0 col12" >2015</th>
#       <th id="T_34397_level0_col13" class="col_heading level0 col13" >2016</th>
#       <th id="T_34397_level0_col14" class="col_heading level0 col14" >2017</th>
#       <th id="T_34397_level0_col15" class="col_heading level0 col15" >2018</th>
#       <th id="T_34397_level0_col16" class="col_heading level0 col16" >2019</th>
#       <th id="T_34397_level0_col17" class="col_heading level0 col17" >2020</th>
#       <th id="T_34397_level0_col18" class="col_heading level0 col18" >2021</th>
#       <th id="T_34397_level0_col19" class="col_heading level0 col19" >2022</th>
#       <th id="T_34397_level0_col20" class="col_heading level0 col20" >2023</th>
#       <th id="T_34397_level0_col21" class="col_heading level0 col21" >2024</th>
#       <th id="T_34397_level0_col22" class="col_heading level0 col22" >avg_share</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >commodity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34397_level0_row0" class="row_heading level0 row0" >[27] Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral waxes</th>
#       <td id="T_34397_row0_col0" class="data row0 col0" >25.73%</td>
#       <td id="T_34397_row0_col1" class="data row0 col1" >25.93%</td>
#       <td id="T_34397_row0_col2" class="data row0 col2" >27.69%</td>
#       <td id="T_34397_row0_col3" class="data row0 col3" >27.40%</td>
#       <td id="T_34397_row0_col4" class="data row0 col4" >19.81%</td>
#       <td id="T_34397_row0_col5" class="data row0 col5" >29.03%</td>
#       <td id="T_34397_row0_col6" class="data row0 col6" >28.28%</td>
#       <td id="T_34397_row0_col7" class="data row0 col7" >29.64%</td>
#       <td id="T_34397_row0_col8" class="data row0 col8" >33.87%</td>
#       <td id="T_34397_row0_col9" class="data row0 col9" >33.35%</td>
#       <td id="T_34397_row0_col10" class="data row0 col10" >31.45%</td>
#       <td id="T_34397_row0_col11" class="data row0 col11" >29.02%</td>
#       <td id="T_34397_row0_col12" class="data row0 col12" >23.01%</td>
#       <td id="T_34397_row0_col13" class="data row0 col13" >19.21%</td>
#       <td id="T_34397_row0_col14" class="data row0 col14" >21.85%</td>
#       <td id="T_34397_row0_col15" class="data row0 col15" >23.21%</td>
#       <td id="T_34397_row0_col16" class="data row0 col16" >20.34%</td>
#       <td id="T_34397_row0_col17" class="data row0 col17" >15.63%</td>
#       <td id="T_34397_row0_col18" class="data row0 col18" >19.46%</td>
#       <td id="T_34397_row0_col19" class="data row0 col19" >24.32%</td>
#       <td id="T_34397_row0_col20" class="data row0 col20" >22.98%</td>
#       <td id="T_34397_row0_col21" class="data row0 col21" >20.97%</td>
#       <td id="T_34397_row0_col22" class="data row0 col22" >25.10%</td>
#     </tr>
#     <tr>
#       <th id="T_34397_level0_row1" class="row_heading level0 row1" >[15] Animal or vegetable fats and oils and their cleavage products; prepared animal fats; animal or vegetable waxes</th>
#       <td id="T_34397_row1_col0" class="data row1 col0" >4.92%</td>
#       <td id="T_34397_row1_col1" class="data row1 col1" >6.18%</td>
#       <td id="T_34397_row1_col2" class="data row1 col2" >5.78%</td>
#       <td id="T_34397_row1_col3" class="data row1 col3" >6.02%</td>
#       <td id="T_34397_row1_col4" class="data row1 col4" >8.96%</td>
#       <td id="T_34397_row1_col5" class="data row1 col5" >11.40%</td>
#       <td id="T_34397_row1_col6" class="data row1 col6" >10.49%</td>
#       <td id="T_34397_row1_col7" class="data row1 col7" >10.34%</td>
#       <td id="T_34397_row1_col8" class="data row1 col8" >10.64%</td>
#       <td id="T_34397_row1_col9" class="data row1 col9" >11.21%</td>
#       <td id="T_34397_row1_col10" class="data row1 col10" >10.53%</td>
#       <td id="T_34397_row1_col11" class="data row1 col11" >11.97%</td>
#       <td id="T_34397_row1_col12" class="data row1 col12" >12.42%</td>
#       <td id="T_34397_row1_col13" class="data row1 col13" >12.56%</td>
#       <td id="T_34397_row1_col14" class="data row1 col14" >13.60%</td>
#       <td id="T_34397_row1_col15" class="data row1 col15" >11.30%</td>
#       <td id="T_34397_row1_col16" class="data row1 col16" >10.52%</td>
#       <td id="T_34397_row1_col17" class="data row1 col17" >12.69%</td>
#       <td id="T_34397_row1_col18" class="data row1 col18" >14.21%</td>
#       <td id="T_34397_row1_col19" class="data row1 col19" >12.04%</td>
#       <td id="T_34397_row1_col20" class="data row1 col20" >10.99%</td>
#       <td id="T_34397_row1_col21" class="data row1 col21" >10.13%</td>
#       <td id="T_34397_row1_col22" class="data row1 col22" >10.41%</td>
#     </tr>
#     <tr>
#       <th id="T_34397_level0_row2" class="row_heading level0 row2" >[85] Electrical machinery and equipment and parts thereof; sound recorders and reproducers; television image and sound recorders and reproducers, parts and accessories of such articles</th>
#       <td id="T_34397_row2_col0" class="data row2 col0" >10.02%</td>
#       <td id="T_34397_row2_col1" class="data row2 col1" >9.18%</td>
#       <td id="T_34397_row2_col2" class="data row2 col2" >8.56%</td>
#       <td id="T_34397_row2_col3" class="data row2 col3" >7.23%</td>
#       <td id="T_34397_row2_col4" class="data row2 col4" >6.64%</td>
#       <td id="T_34397_row2_col5" class="data row2 col5" >6.01%</td>
#       <td id="T_34397_row2_col6" class="data row2 col6" >6.94%</td>
#       <td id="T_34397_row2_col7" class="data row2 col7" >6.57%</td>
#       <td id

# %% [markdown]
# **Import**

# %%
commodity_import_share_per_year = commodity_export_per_year.sort_values(by=['year', 'import_share'], ascending=[True, False]).drop(['export_share', 'export'], axis=1)
commodity_import_share_per_year
# Out:
#       year  com_label                                          commodity  \
# 26    2003          2  [27] Mineral fuels, mineral oils and products ...
# 82    2003          8  [84] Nuclear reactors, boilers, machinery and ...
# 28    2003          2                             [29] Organic chemicals
# 85    2003          8  [87] Vehicles; other than railway or tramway r...
# 83    2003          8  [85] Electrical machinery and equipment and pa...
# ...    ...        ...                                                ...
# 2093  2024          5     [57] Carpets and other textile floor coverings
# 2081  2024          4                     [45] Cork and articles of cork
# 2050  2024          1  [14] Vegetable plaiting materials; vegetable p...
# 2086  2024          5                                          [50] Silk
# 2082  2024          4  [46] Manufactures of straw, esparto or other p...
#
#           import                       com_label_name  import_share
# 26    7667923941  Raw materials, edible, except fuels      0.235569
# 82    4303040825             Other manufactured goods      0.132195
# 28    2163896816  Raw materials, edible, except fuels      0.066478
# 85    1890290768             Other manufactured goods      0.058072
# 83    1763077039             Other manufactured goods      0.054164
# ...          ...                                  ...           ...
# 2093     8425094         Chemicals and other products      0.000036
# 2081     6054779     Animal & vegetable oils and fats      0.000026
# 2050     3090436             Beverages and cigarettes      0.000013
# 2086     2363218         Chemicals and other products      0.000010
# 2082      876397     Animal & vegetable oils and fats      0.000004
#
# [2134 rows x 6 columns]

# %%
commodity_import_share_pivot_table = commodity_import_share_per_year.pivot_table(index='commodity', columns='year', values='import_share')
commodity_import_share_pivot_table['avg_share'] = commodity_import_share_pivot_table.mean(axis=1)
commodity_import_share_pivot_table = commodity_import_share_pivot_table.sort_values(by='avg_share', ascending=False)
commodity_import_share_pivot_table.to_csv('awikwik2.csv', sep="|")
print("\nSorted and Formatted Pivot Table (Import Share as Percentages, Max Highlighted)")
display(commodity_import_share_pivot_table.style.format("{:.2%}").highlight_max(axis=0, color='#ffffb3'))
# Out:
# Sorted and Formatted Pivot Table (Import Share as Percentages, Max Highlighted)
# <style type="text/css">
# #T_86fc4_row0_col0, #T_86fc4_row0_col1, #T_86fc4_row0_col2, #T_86fc4_row0_col3, #T_86fc4_row0_col4, #T_86fc4_row0_col5, #T_86fc4_row0_col6, #T_86fc4_row0_col7, #T_86fc4_row0_col8, #T_86fc4_row0_col9, #T_86fc4_row0_col10, #T_86fc4_row0_col11, #T_86fc4_row0_col12, #T_86fc4_row0_col14, #T_86fc4_row0_col15, #T_86fc4_row0_col18, #T_86fc4_row0_col19, #T_86fc4_row0_col20, #T_86fc4_row0_col21, #T_86fc4_row0_col22, #T_86fc4_row1_col13, #T_86fc4_row1_col16, #T_86fc4_row1_col17 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_86fc4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_86fc4_level0_col0" class="col_heading level0 col0" >2003</th>
#       <th id="T_86fc4_level0_col1" class="col_heading level0 col1" >2004</th>
#       <th id="T_86fc4_level0_col2" class="col_heading level0 col2" >2005</th>
#       <th id="T_86fc4_level0_col3" class="col_heading level0 col3" >2006</th>
#       <th id="T_86fc4_level0_col4" class="col_heading level0 col4" >2007</th>
#       <th id="T_86fc4_level0_col5" class="col_heading level0 col5" >2008</th>
#       <th id="T_86fc4_level0_col6" class="col_heading level0 col6" >2009</th>
#       <th id="T_86fc4_level0_col7" class="col_heading level0 col7" >2010</th>
#       <th id="T_86fc4_level0_col8" class="col_heading level0 col8" >2011</th>
#       <th id="T_86fc4_level0_col9" class="col_heading level0 col9" >2012</th>
#       <th id="T_86fc4_level0_col10" class="col_heading level0 col10" >2013</th>
#       <th id="T_86fc4_level0_col11" class="col_heading level0 col11" >2014</th>
#       <th id="T_86fc4_level0_col12" class="col_heading level0 col12" >2015</th>
#       <th id="T_86fc4_level0_col13" class="col_heading level0 col13" >2016</th>
#       <th id="T_86fc4_level0_col14" class="col_heading level0 col14" >2017</th>
#       <th id="T_86fc4_level0_col15" class="col_heading level0 col15" >2018</th>
#       <th id="T_86fc4_level0_col16" class="col_heading level0 col16" >2019</th>
#       <th id="T_86fc4_level0_col17" class="col_heading level0 col17" >2020</th>
#       <th id="T_86fc4_level0_col18" class="col_heading level0 col18" >2021</th>
#       <th id="T_86fc4_level0_col19" class="col_heading level0 col19" >2022</th>
#       <th id="T_86fc4_level0_col20" class="col_heading level0 col20" >2023</th>
#       <th id="T_86fc4_level0_col21" class="col_heading level0 col21" >2024</th>
#       <th id="T_86fc4_level0_col22" class="col_heading level0 col22" >avg_share</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >commodity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86fc4_level0_row0" class="row_heading level0 row0" >[27] Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral waxes</th>
#       <td id="T_86fc4_row0_col0" class="data row0 col0" >23.56%</td>
#       <td id="T_86fc4_row0_col1" class="data row0 col1" >25.37%</td>
#       <td id="T_86fc4_row0_col2" class="data row0 col2" >30.36%</td>
#       <td id="T_86fc4_row0_col3" class="data row0 col3" >31.18%</td>
#       <td id="T_86fc4_row0_col4" class="data row0 col4" >17.33%</td>
#       <td id="T_86fc4_row0_col5" class="data row0 col5" >23.75%</td>
#       <td id="T_86fc4_row0_col6" class="data row0 col6" >19.72%</td>
#       <td id="T_86fc4_row0_col7" class="data row0 col7" >20.29%</td>
#       <td id="T_86fc4_row0_col8" class="data row0 col8" >23.02%</td>
#       <td id="T_86fc4_row0_col9" class="data row0 col9" >22.31%</td>
#       <td id="T_86fc4_row0_col10" class="data row0 col10" >24.40%</td>
#       <td id="T_86fc4_row0_col11" class="data row0 col11" >24.66%</td>
#       <td id="T_86fc4_row0_col12" class="data row0 col12" >17.55%</td>
#       <td id="T_86fc4_row0_col13" class="data row0 col13" >14.19%</td>
#       <td id="T_86fc4_row0_col14" class="data row0 col14" >16.24%</td>
#       <td id="T_86fc4_row0_col15" class="data row0 col15" >16.74%</td>
#       <td id="T_86fc4_row0_col16" class="data row0 col16" >13.71%</td>
#       <td id="T_86fc4_row0_col17" class="data row0 col17" >11.15%</td>
#       <td id="T_86fc4_row0_col18" class="data row0 col18" >14.70%</td>
#       <td id="T_86fc4_row0_col19" class="data row0 col19" >18.91%</td>
#       <td id="T_86fc4_row0_col20" class="data row0 col20" >18.08%</td>
#       <td id="T_86fc4_row0_col21" class="data row0 col21" >17.40%</td>
#       <td id="T_86fc4_row0_col22" class="data row0 col22" >20.21%</td>
#     </tr>
#     <tr>
#       <th id="T_86fc4_level0_row1" class="row_heading level0 row1" >[84] Nuclear reactors, boilers, machinery and mechanical appliances; parts thereof</th>
#       <td id="T_86fc4_row1_col0" class="data row1 col0" >13.22%</td>
#       <td id="T_86fc4_row1_col1" class="data row1 col1" >13.58%</td>
#       <td id="T_86fc4_row1_col2" class="data row1 col2" >14.01%</td>
#       <td id="T_86fc4_row1_col3" class="data row1 col3" >12.14%</td>
#       <td id="T_86fc4_row1_col4" class="data row1 col4" >10.50%</td>
#       <td id="T_86fc4_row1_col5" class="data row1 col5" >15.19%</td>
#       <td id="T_86fc4_row1_col6" class="data row1 col6" >16.01%</td>
#       <td id="T_86fc4_row1_col7" class="data row1 col7" >14.76%</td>
#       <td id="T_86fc4_row1_col8" class="data row1 col8" >13.94%</td>
#       <td id="T_86fc4_row1_col9" class="data row1 col9" >14.83%</td>
#       <td id="T_86fc4_row1_col10" class="data row1 col10" >14.62%</td>
#       <td id="T_86fc4_row1_col11" class="data row1 col11" >14.50%</td>
#       <td id="T_86fc4_row1_col12" class="data row1 col12" >15.68%</td>
#       <td id="T_86fc4_row1_col13" class="data row1 col13" >15.53%</td>
#       <td id="T_86fc4_row1_col14" class="data row1 col14" >13.87%</td>
#       <td id="T_86fc4_row1_col15" class="data row1 col15" >14.41%</td>
#       <td id="T_86fc4_row1_col16" class="data row1 col16" >15.66%</td>
#       <td id="T_86fc4_row1_col17" class="data row1 col17" >15.40%</td>
#       <td id="T_86fc4_row1_col18" class="data row1 col18" >13.17%</td>
#       <td id="T_86fc4_row1_col19" class="data row1 col19" >13.30%</td>
#       <td id="T_86fc4_row1_col20" class="data row1 col20" >14.49%</td>
#       <td id="T_86fc4_row1_col21" class="data row1 col21" >14.34%</td>
#       <td id="T_86fc4_row1_col22" class="data row1 col22" >14.23%</td>
#     </tr>
#     <tr>
#       <th id="T_86fc4_level0_row2" class="row_heading level0 row2" >[85] Electrical machinery and equipment and parts thereof; sound recorders and reproducers; television image and sound recorders and reproducers, parts and accessories of such articles</th>
#       <td id="T_86fc4_row2_col0" class="data row2 col0" >5.42%</td>
#       <td id="T_86fc4_row2_col1" class="data row2 col1" >5.95%</td>
#       <td id="T_86fc4_row2_col2" class="data row2 col2" >5.75%</td>
#       <td id="T_86fc4_row2_col3" class="data row2 col3" >5.07%</td>
#       <td id="T_86fc4_row2_col4" class="data row2 col4" >4.68%</td>
#       <td id="T_86fc4_row2_col5" class="data row2 col5" >10.13%</td>
#       <td id="T_86fc4_row2_col6" class="data row2 col6" >10.85%</td>
#       <td id="T_86fc4_row2_col7" class="data row2 col7" >11.52%</td>
#       <td id="T_86fc4_row2_col8" class

# %% [markdown]
# ## Year Average Growth

# %%
yearly_export_data = yearly_export_data.reset_index()
yearly_export_data_melted = yearly_export_data.melt(id_vars=['year'], value_vars=['export', 'import'], var_name='Trade Type', value_name='Value')
fig = px.line(yearly_export_data_melted, x='year', y='Value', color='Trade Type', markers=True)
fig.update_layout(xaxis_title="Year", yaxis_title="Value US$", template="plotly_white")
fig.update_xaxes(tickmode='linear')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86812b89-b358-4288-ab95-d01a4b9fe199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86812b89-b358-4288-ab95-d01a4b9fe199")) {                    Plotly.newPlot(                        "86812b89-b358-4288-ab95-d01a4b9fe199",                        [{"hovertemplate":"Trade Type=export\u003cbr\u003eyear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"export","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"export","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[61058246995.0,71584608736.0,85659952615.0,100798624280.0,114100890751.0,137020424402.0,116509991781.0,157779103470.0,203496626408.0,190031845232.0,182551798697.0,175979986988.0,150282256805.34,145186211246.48,168828175936.07,180012674002.03,167682996134.3,163191838162.87,231609479580.31,291904299995.16,258857475676.36002,264705937076.44],"yaxis":"y","type":"scatter"},{"hovertemplate":"Trade Type=import\u003cbr\u003eyear=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"import","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"import","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[32550690611.0,46524531358.0,57700882616.0,61065465536.0,74473430118.0,129197306224.0,96829162576.0,135663284048.0,177435555736.0,191689471527.0,186628669880.0,178178816605.0,142694804223.0,135652816501.0,156985563722.0,188711350191.0,171275736997.0,141568794630.0,196189979075.0,237447056598.0,221886223535.0,233652364205.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %%
export_avg_growth = yearly_export_data['export_growth'].mean()
import_avg_growth = yearly_export_data['import_growth'].mean()
print(f"Export yearly-averaged growth: {export_avg_growth:.2f}%")
print(f"Import yearly-averaged growth: {import_avg_growth:.2f}%")
# Out:
# Export yearly-averaged growth: 8.45%
# Import yearly-averaged growth: 12.28%

# %% [markdown]
# ## Compound Annual Growth Rate
# ![image.png](attachment:878377c8-31c1-412c-be1f-cc5eff0190e5.png)

# %%
N = len(yearly_export_data) - 1

export_0 = yearly_export_data['export'].iloc[0]
export_N = yearly_export_data['export'].iloc[-1]

export_cagr = ((export_N / export_0) ** (1 / N) - 1) * 100
print(f"Export CAGR: {export_cagr:.2f}%")

import_0 = yearly_export_data['import'].iloc[0]
import_N = yearly_export_data['import'].iloc[-1]

import_cagr = ((import_N / import_0) ** (1 / N) - 1) * 100
print(f"Import CAGR: {import_cagr:.2f}%")
# Out:
# Export CAGR: 7.23%
# Import CAGR: 9.84%

# %%
merged_ex_price_data = yearly_export_data.merge(price_index_data, left_on='year', right_on='year').drop('index', axis=1)
merged_ex_price_data.head()
# Out:
#    year        export       import  trade_balance  export_growth  \
# 0  2003  6.105825e+10  32550690611   2.850756e+10            NaN
# 1  2004  7.158461e+10  46524531358   2.506008e+10      17.239869
# 2  2005  8.565995e+10  57700882616   2.795907e+10      19.662528
# 3  2006  1.007986e+11  61065465536   3.973316e+10      17.672986
# 4  2007  1.141009e+11  74473430118   3.962746e+10      13.196873
#
#    import_growth  who_com_prices  energy_index  non_energy_index  \
# 0            NaN           43.83         41.40             48.76
# 1      42.929475           54.49         53.44             56.60
# 2      24.022491           70.74         75.39             61.29
# 3       5.831077           82.16         85.40             75.56
# 4      21.956706           92.89         94.37             89.82
#
#    precious_metal_index
# 0                 29.08
# 1                 33.97
# 2                 36.95
# 3                 51.57
# 4                 59.49

# %% [markdown]
# # Granger Causality

# %%
merged_data_all = merged_ex_price_data.merge(gdp_data.drop(['export', 'import'], axis=1), on='year')
merged_data_all
# Out:
#     year        export        import  trade_balance  export_growth  \
# 0   2003  6.105825e+10   32550690611   2.850756e+10            NaN
# 1   2004  7.158461e+10   46524531358   2.506008e+10      17.239869
# 2   2005  8.565995e+10   57700882616   2.795907e+10      19.662528
# 3   2006  1.007986e+11   61065465536   3.973316e+10      17.672986
# 4   2007  1.141009e+11   74473430118   3.962746e+10      13.196873
# 5   2008  1.370204e+11  129197306224   7.823118e+09      20.087077
# 6   2009  1.165100e+11   96829162576   1.968083e+10     -14.968887
# 7   2010  1.577791e+11  135663284048   2.211582e+10      35.421092
# 8   2011  2.034966e+11  177435555736   2.606107e+10      28.975651
# 9   2012  1.900318e+11  191689471527  -1.657626e+09      -6.616710
# 10  2013  1.825518e+11  186628669880  -4.076871e+09      -3.936207
# 11  2014  1.759800e+11  178178816605  -2.198830e+09      -3.599971
# 12  2015  1.502823e+11  142694804223   7.587453e+09     -14.602644
# 13  2016  1.451862e+11  135652816501   9.533395e+09      -3.390983
# 14  2017  1.688282e+11  156985563722   1.184261e+10      16.283891
# 15  2018  1.800127e+11  188711350191  -8.698676e+09       6.624782
# 16  2019  1.676830e+11  171275736997  -3.592741e+09      -6.849339
# 17  2020  1.631918e+11  141568794630   2.162304e+10      -2.678362
# 18  2021  2.316095e+11  196189979075   3.541950e+10      41.924671
# 19  2022  2.919043e+11  237447056598   5.445724e+10      26.032967
# 20  2023  2.588575e+11  221886223535   3.697125e+10     -11.321116
# 21  2024  2.647059e+11  233652364205   3.105357e+10       2.259336
#
#     import_growth  who_com_prices  energy_index  non_energy_index  \
# 0             NaN           43.83         41.40             48.76
# 1       42.929475           54.49         53.44             56.60
# 2       24.022491           70.74         75.39             61.29
# 3        5.831077           82.16         85.40             75.56
# 4       21.956706           92.89         94.37             89.82
# 5       73.481074          121.38        129.03            105.72
# 6      -25.053265           80.88         79.36             83.94
# 7       40.105812          100.00        100.00            100.00
# 8       30.791140          130.07        135.22            119.56
# 9        8.033292          126.01        134.12            109.51
# 10      -2.640104          121.60        131.65            101.29
# 11      -4.527629          112.47        120.40             96.47
# 12     -19.914832           71.19         66.10             81.62
# 13      -4.934999           63.69         56.02             79.36
# 14      15.725989           74.04         69.36             83.73
# 15      20.209366           87.96         89.36             85.13
# 16      -9.239303           79.34         78.25             81.56
# 17     -17.344513           63.07         52.68             84.12
# 18      38.582786          100.90         95.38            112.09
# 19      21.029146          142.52        152.57            122.14
# 20      -6.553391          108.04        106.95            110.24
# 21       5.302781          105.14        101.52            112.47
#
#     precious_metal_index                gdp
# 0                  29.08   2013674600000000
# 1                  33.97   2295826200000000
# 2                  36.95   2774281100000000
# 3                  51.57   3339216800000000
# 4                  59.49   3950893200000000
# 5                  72.66   4948688400000000
# 6                  78.01   5606203400000000
# 7                 100.00   6864133100000000
# 8                 136.27   7831726000000000
# 9                 138.46   8615704500000000
# 10                115.09   9546134000000000
# 11                101.12  10569705300000000
# 12                 90.64  11526332800000000
# 13                 97.45  12401728500000000
# 14                 97.84  13589825700000000
# 15                 97.17  14838756000000000
# 16                105.44  15832657200000000
# 17                133.54  15443353200000000
# 18                140.17  16976751400000000
# 19                136.80  19588089900000000
# 20                147.34  20892376700000000
# 21                180.17  22138964000000000

# %%
def check_stationarity(series):
    result = adfuller(series.dropna())
    print(f"ADF Statistic: {result[0]}")
    print(f"P-Value: {result[1]}")
    return result[1] < 0.05

def make_stationary(data, columns):
    for col in columns:
        if data[col].isna().any() or (data[col] == float('inf')).any():
            print(f"Column {col} has NaN or infinite values, cleaning it.")
            data[col] = data[col].fillna(method='ffill').fillna(method='bfill')

        while not check_stationarity(data[col]):
            print(f"Column {col} is not stationary. Differencing applied.")
            data[col] = data[col].diff().dropna()
            if data[col].isna().any():
                print(f"Column {col} has NaN values after differencing. Dropping NaNs.")
                data[col] = data[col].dropna()
        print(f"Column {col} is stationary now.", end="\n\n")

# %% [markdown]
# ## ADF and Differencing

# %%
# make_stationary(gdp_data, ['export', 'import', 'gdp', ])
make_stationary(merged_data_all, ['export', 'import', 'gdp', 'who_com_prices'])
merged_data_all.dropna(inplace=True)
merged_data_all.head()
# Out:
# ADF Statistic: 0.19289192330432417
# P-Value: 0.9718600938153541
# Column export is not stationary. Differencing applied.
# Column export has NaN values after differencing. Dropping NaNs.
# ADF Statistic: -3.964803882195709
# P-Value: 0.001606446155133737
# Column export is stationary now.
#
# ADF Statistic: -1.5568733130418417
# P-Value: 0.5052131171009894
# Column import is not stationary. Differencing applied.
# Column import has NaN values after differencing. Dropping NaNs.
# ADF Statistic: -3.21674058443748
# P-Value: 0.01903588908649944
# Column import is stationary now.
#
# ADF Statistic: 2.9336277206229022
# P-Value: 1.0
# Column gdp is not stationary. Differencing applied.
# Column gdp has NaN values after differencing. Dropping NaNs.
# ADF Statistic: 0.6270400807020705
# P-Value: 0.9882634999948895
# Column gdp is not stationary. Differencing applied.
# Column gdp has NaN values after differencing. Dropping NaNs.
# ADF Statistic: -6.078806098132146
# P-Value: 1.1048963365714077e-07
# Column gdp is stationary now.
#
# ADF Statistic: -4.906612694990339
# P-Value: 3.385536255149876e-05
# Column who_com_prices is stationary now.
#    year        export        import  trade_balance  export_growth  \
# 2  2005  1.407534e+10  1.117635e+10   2.795907e+10      19.662528
# 3  2006  1.513867e+10  3.364583e+09   3.973316e+10      17.672986
# 4  2007  1.330227e+10  1.340796e+10   3.962746e+10      13.196873
# 5  2008  2.291953e+10  5.472388e+10   7.823118e+09      20.087077
# 6  2009 -2.051043e+10 -3.236814e+10   1.968083e+10     -14.968887
#
#    import_growth  who_com_prices  energy_index  non_energy_index  \
# 2      24.022491           70.74         75.39             61.29
# 3       5.831077           82.16         85.40             75.56
# 4      21.956706           92.89         94.37             89.82
# 5      73.481074          121.38        129.03            105.72
# 6     -25.053265           80.88         79.36             83.94
#
#    precious_metal_index           gdp
# 2                 36.95  1.963033e+14
# 3                 51.57  8.648080e+13
# 4                 59.49  4.674070e+13
# 5                 72.66  3.861188e+14
# 6                 78.01 -3.402802e+14

# %% [markdown]
# ## Causality Test

# %%
merged_data_all = merged_data_all.set_index('year')

# %%
model = VAR(merged_data_all[['gdp', 'export', 'import', 'who_com_prices']])
lag_order = model.select_order(maxlags=3)
print(lag_order.summary())
optimal_lag = lag_order.aic
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       169.1       169.3   2.665e+73       169.1
# 1       168.0      169.0*  9.947e+72*       168.1
# 2       167.6       169.4   1.024e+73       167.8
# 3      167.3*       169.8   3.079e+73      167.5*
# -------------------------------------------------
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.

# %% [markdown]
# ### Individual Inferential Statistics

# %%
var_model = model.fit(optimal_lag)
var_model.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 28, Jun, 2025
# Time:                     10:58:50
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    169.820
# Nobs:                     17.0000    HQIC:                   167.525
# Log likelihood:          -1466.29    FPE:                3.07863e+73
# AIC:                      167.271    Det(Omega_mle):     3.17445e+72
# --------------------------------------------------------------------
# Results for equation gdp
# ===================================================================================================
#                               coefficient               std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------
# const                -831599217220.236206  1057665077661312.625000           -0.001           0.999
# L1.gdp                          -1.115684                 0.385011           -2.898           0.004
# L1.export                    26875.069095             16240.522776            1.655           0.098
# L1.import                    30807.264575             22903.632934            1.345           0.179
# L1.who_com_prices  -69175274897765.140625    32724672412972.703125           -2.114           0.035
# L2.gdp                          -0.985290                 0.390815           -2.521           0.012
# L2.export                    12155.867947             21846.937858            0.556           0.578
# L2.import                   -40908.927269             16938.448840           -2.415           0.016
# L2.who_com_prices   99650277453571.468750    42452416199165.140625            2.347           0.019
# L3.gdp                          -1.461192                 0.685243           -2.132           0.033
# L3.export                    20570.114624             17616.860740            1.168           0.243
# L3.import                    -7351.363253             14443.609290           -0.509           0.611
# L3.who_com_prices  -31456892759181.726562    25284612979640.054688           -1.244           0.213
# ===================================================================================================
#
# Results for equation export
# ==========================================================================================
#                           coefficient          std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                -17331333.888792  46277296811.777351           -0.000           1.000
# L1.gdp                      -0.000022            0.000017           -1.307           0.191
# L1.export                    2.107230            0.710591            2.965           0.003
# L1.import                   -0.194146            1.002130           -0.194           0.846
# L1.who_com_prices  -1805390769.994895   1431842092.840912           -1.261           0.207
# L2.gdp                      -0.000028            0.000017           -1.620           0.105
# L2.export                    0.163542            0.955895            0.171           0.864
# L2.import                   -0.237278            0.741128           -0.320           0.749
# L2.who_com_prices   1675224269.296936   1857471808.722205            0.902           0.367
# L3.gdp                      -0.000005            0.000030           -0.155           0.877
# L3.export                    0.671773            0.770812            0.872           0.383
# L3.import                   -0.163988            0.631969           -0.259           0.795
# L3.who_com_prices     62538058.728598   1106308191.830471            0.057           0.955
# ==========================================================================================
#
# Results for equation import
# ==========================================================================================
#                           coefficient          std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                -19929497.091731  65534621638.819931           -0.000           1.000
# L1.gdp                      -0.000030            0.000024           -1.260           0.208
# L1.export                    2.271462            1.006289            2.257           0.024
# L1.import                    0.015398            1.419146            0.011           0.991
# L1.who_com_prices  -2036000233.026025   2027673098.161271           -1.004           0.315
# L2.gdp                      -0.000019            0.000024           -0.793           0.428
# L2.export                    0.204907            1.353671            0.151           0.880
# L2.import                   -0.391378            1.049533           -0.373           0.709
# L2.who_com_prices   1964221594.136540   2630419678.238528            0.747           0.455
# L3.gdp                      -0.000006            0.000042           -0.140           0.888
# L3.export                    0.866745            1.091569            0.794           0.427
# L3.import                   -0.458606            0.894949           -0.512           0.608
# L3.who_com_prices     -9429791.867782   1566675103.397259           -0.006           0.995
# ==========================================================================================
#
# Results for equation who_com_prices
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.002284        44.434971           -0.000           1.000
# L1.gdp                   -0.000000         0.000000           -1.178           0.239
# L1.export                 0.000000         0.000000            2.409           0.016
# L1.import                -0.000000         0.000000           -0.249           0.804
# L1.who_com_prices        -0.365932         1.374840           -0.266           0.790
# L2.gdp                   -0.000000         0.000000           -1.736           0.083
# L2.export                 0.000000         0.000000            0.579           0.562
# L2.import                -0.000000         0.000000           -0.092           0.927
# L2.who_com_prices         0.731181         1.783525            0.410           0.682
# L3.gdp                   -0.000000         0.000000           -0.085           0.933
# L3.export                 0.000000         0.000000            0.893           0.372
# L3.import                -0.000000         0.000000           -0.527           0.598
# L3.who_com_prices         0.495844         1.062265            0.467           0.641
# ====================================================================================
#
# Correlation matrix of residuals
#                        gdp    export    import  who_com_prices
# gdp               1.000000  0.628686  0.621858        0.538160
# export            0.628686  1.000000  0.691830        0.718960
# import            0.621858  0.691830  1.000000        0.939759
# who_com_prices    0.538160  0.718960  0.939759        1.000000

# %% [markdown]
# ### Joint Causality

# %%
granger_test = var_model.test_causality(caused='gdp', causing='export', kind='f', signif=0.1)
print(granger_test.summary())
# Out:
# Granger causality F-test. H_0: export does not Granger-cause gdp. Conclusion: fail to reject H_0 at 10% significance level.
# =======================================================
# Test statistic Critical value p-value         df
# -------------------------------------------------------
#          1.624          2.462   0.223 (3, np.int64(16))
# -------------------------------------------------------

# %%
granger_test = var_model.test_causality(caused='gdp', causing='import', kind='f', signif=0.1)
print(granger_test.summary())
# Out:
# Granger causality F-test. H_0: import does not Granger-cause gdp. Conclusion: fail to reject H_0 at 10% significance level.
# =======================================================
# Test statistic Critical value p-value         df
# -------------------------------------------------------
#          2.112          2.462   0.139 (3, np.int64(16))
# -------------------------------------------------------

# %%
granger_test = var_model.test_causality(caused='export', causing='who_com_prices', kind='f', signif=0.1)
print(granger_test.summary())
# Out:
# Granger causality F-test. H_0: who_com_prices does not Granger-cause export. Conclusion: fail to reject H_0 at 10% significance level.
# =======================================================
# Test statistic Critical value p-value         df
# -------------------------------------------------------
#         0.6210          2.462   0.612 (3, np.int64(16))
# -------------------------------------------------------

# %%
granger_test = var_model.test_causality(caused='import', causing='who_com_prices', kind='f', signif=0.1)
print(granger_test.summary())
# Out:
# Granger causality F-test. H_0: who_com_prices does not Granger-cause import. Conclusion: fail to reject H_0 at 10% significance level.
# =======================================================
# Test statistic Critical value p-value         df
# -------------------------------------------------------
#         0.3846          2.462   0.766 (3, np.int64(16))
# -------------------------------------------------------

# %% [markdown]
# # Forecasting

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
errors = {}

# %%
yearly_trade_data_cleaned = yearly_export_data.merge(price_index_data, on='year')[['year', 'export', 'import', 'who_com_prices']]
yearly_trade_data_cleaned['year'] = pd.to_datetime(yearly_trade_data_cleaned['year'], format='%Y')
yearly_trade_data_cleaned = yearly_trade_data_cleaned.set_index('year')
yearly_trade_data_cleaned = yearly_trade_data_cleaned.asfreq('YS')

train_size = int(len(yearly_trade_data_cleaned) * 0.8)
train, test = yearly_trade_data_cleaned[:train_size], yearly_trade_data_cleaned[train_size:]

train = train.asfreq('YS')
test = test.asfreq('YS')

# %% [markdown]
# ## ARDL

# %%
ardl_model_exp = ARDL(train['export'], lags=3, exog=train[['who_com_prices']])
ardl_model_imp = ARDL(train['import'], lags=3, exog=train[['who_com_prices']])

ardl_fit_exp = ardl_model_exp.fit()
ardl_fit_imp = ardl_model_imp.fit()

ardl_forecast_exp = ardl_fit_exp.predict(start=test.index[0], end=test.index[-1], exog_oos=test[['who_com_prices']])
ardl_forecast_imp = ardl_fit_imp.predict(start=test.index[0], end=test.index[-1], exog_oos=test[['who_com_prices']])

errors['ARDL_export'] = (mean_squared_error(test['export'], ardl_forecast_exp), rmse(test['export'], ardl_forecast_exp))
errors['ARDL_import'] = (mean_squared_error(test['import'], ardl_forecast_imp), rmse(test['import'], ardl_forecast_imp))

# %% [markdown]
# ## Moving Average

# %%
mov_avg_exp = train['export'].rolling(window=2).mean().iloc[-1]
mov_avg_imp = train['import'].rolling(window=2).mean().iloc[-1]

mov_avg_forecast_exp = np.full(len(test), mov_avg_exp)
mov_avg_forecast_imp = np.full(len(test), mov_avg_imp)

errors['MA_export'] = (mean_squared_error(test['export'], mov_avg_forecast_exp), rmse(test['export'], mov_avg_forecast_exp))
errors['MA_import'] = (mean_squared_error(test['import'], mov_avg_forecast_imp), rmse(test['import'], mov_avg_forecast_imp))

# %% [markdown]
# ## Exponential Smoothing

# %%
exp_smooth_exp = ExponentialSmoothing(train['export'], trend='add', damped_trend=True).fit()
exp_smooth_imp = ExponentialSmoothing(train['import'], trend='add', damped_trend=True).fit()

exp_smooth_forecast_exp = exp_smooth_exp.forecast(len(test))
exp_smooth_forecast_imp = exp_smooth_imp.forecast(len(test))

errors['ES_export'] = (mean_squared_error(test['export'], exp_smooth_forecast_exp), rmse(test['export'], exp_smooth_forecast_exp))
errors['ES_import'] = (mean_squared_error(test['import'], exp_smooth_forecast_imp), rmse(test['import'], exp_smooth_forecast_imp))
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
best_export_model = min(errors, key=lambda x: errors[x][0] if 'export' in x else float('inf'))
best_import_model = min(errors, key=lambda x: errors[x][0] if 'import' in x else float('inf'))

print("Model Performance (MSE, RMSE):")
for model, (mse, rmse_val) in errors.items():
    print(f"{model}: MSE={mse:.2f}, RMSE={rmse_val:.2f}")

print(f"\nBest Model for Export: {best_export_model}")
print(f"Best Model for Import: {best_import_model}")
# Out:
# Model Performance (MSE, RMSE):
# ARDL_export: MSE=4761517357747899727872.00, RMSE=69003748867.35
# ARDL_import: MSE=566399296440284020736.00, RMSE=23799144867.84
# MA_export: MSE=6573824090946492432384.00, RMSE=81079122411.05
# MA_import: MSE=1934791534747990884352.00, RMSE=43986265296.66
# ES_export: MSE=4321095582701641531392.00, RMSE=65735040752.26
# ES_import: MSE=530669966056879882240.00, RMSE=23036275003.93
#
# Best Model for Export: ES_export
# Best Model for Import: ES_import

# %% [markdown]
# ## Future Predictions

# %%
future_years = 3

if "ARDL" in best_export_model:
    best_model_exp = ARDL(yearly_trade_data_cleaned['export'], lags=2, exog=yearly_trade_data_cleaned[['who_com_prices']]).fit()
    best_model_exp = best_model_imp.predict(start=yearly_trade_data_cleaned.index[-1] + pd.DateOffset(years = 1), end=yearly_trade_data_cleaned.index[-1] + pd.DateOffset(years = 1 + future_years), exog_oos=yearly_trade_data_cleaned[['who_com_prices']])
elif "MA" in best_export_model:
    best_model_exp = yearly_trade_data_cleaned['export'].rolling(window=2).mean().iloc[-1]
    best_model_exp = np.full(future_years, best_model_exp)
else:
    best_model_exp = ExponentialSmoothing(yearly_trade_data_cleaned['export'], trend='add', damped_trend=True).fit()
    best_model_exp = best_model_exp.forecast(future_years)

if "ARDL" in best_import_model:
    best_model_imp = ARDL(yearly_trade_data_cleaned['import'], lags=2, exog=yearly_trade_data_cleaned[['who_com_prices']]).fit()
    best_model_imp = best_model_imp.predict(start=yearly_trade_data_cleaned.index[-1] + pd.DateOffset(years = 1), end=yearly_trade_data_cleaned.index[-1] + pd.DateOffset(years = future_years), exog_oos=yearly_trade_data_cleaned[['who_com_prices']])
elif "MA" in best_import_model:
    best_model_imp = yearly_trade_data_cleaned['import'].rolling(window=2).mean().iloc[-1]
    best_model_imp = np.full(future_years, best_model_imp)
else:
    best_model_imp = ExponentialSmoothing(yearly_trade_data_cleaned['import'], trend='add', damped_trend=True).fit()
    best_model_imp = best_model_imp.forecast(future_years)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
#
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
future_dates = pd.date_range(start=yearly_trade_data_cleaned.index[-1] + pd.DateOffset(years=1), periods=future_years, freq='YS')
future_forecast = pd.DataFrame({'export': best_model_exp, 'import': best_model_imp})

print("\nFuture Forecast:")
future_forecast
# Out:
# Future Forecast:
#                   export        import
# 2025-01-01  2.768278e+11  2.476822e+11
# 2026-01-01  2.887959e+11  2.614828e+11
# 2027-01-01  3.006443e+11  2.751454e+11

# %%
final_data = pd.concat([yearly_trade_data_cleaned, future_forecast])[['export', 'import']]
final_data.index = final_data.index.year
final_data['type'] = ['Actual' if year <= 2024 else 'Predicted' for year in final_data.index]
final_data = final_data.reset_index(names=['year'])
final_data.head()
# Out:
#    year        export        import    type
# 0  2003  6.105825e+10  3.255069e+10  Actual
# 1  2004  7.158461e+10  4.652453e+10  Actual
# 2  2005  8.565995e+10  5.770088e+10  Actual
# 3  2006  1.007986e+11  6.106547e+10  Actual
# 4  2007  1.141009e+11  7.447343e+10  Actual

# %%
final_data_melt = final_data.melt(id_vars=['year', 'type'], value_vars=['export', 'import'], var_name='Trade Type', value_name='Trade Value')
fig = px.line(final_data_melt,
              x='year',
              y='Trade Value',
              color='Trade Type',
              line_dash='type',
              labels={'Trade Value': 'Trade Value (USD)', 'year': 'Year'},
              template="plotly_white",
              markers=True)

fig.update_xaxes(tickmode='linear')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c5776cb-982c-42b3-9273-25d6fd7a3c97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c5776cb-982c-42b3-9273-25d6fd7a3c97")) {                    Plotly.newPlot(                        "9c5776cb-982c-42b3-9273-25d6fd7a3c97",                        [{"hovertemplate":"Trade Type=export\u003cbr\u003etype=Actual\u003cbr\u003eYear=%{x}\u003cbr\u003eTrade Value (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"export, Actual","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"export, Actual","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[61058246995.0,71584608736.0,85659952615.0,100798624280.0,114100890751.0,137020424402.0,116509991781.0,157779103470.0,203496626408.0,190031845232.0,182551798697.0,175979986988.0,150282256805.34,145186211246.48,168828175936.07,180012674002.03,167682996134.3,163191838162.87,231609479580.31,291904299995.16,258857475676.36002,264705937076.44],"yaxis":"y","type":"scatter"},{"hovertemplate":"Trade Type=export\u003cbr\u003etype=Predicted\u003cbr\u003eYear=%{x}\u003cbr\u003eTrade Value (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"export, Predicted","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"export, Predicted","orientation":"v","showlegend":true,"x":[2025,2026,2027],"xaxis":"x","y":[276827842417.9105,288795913183.685,300644303241.8018],"yaxis":"y","type":"scatter"},{"hovertemplate":"Trade Type=import\u003cbr\u003etype=Actual\u003cbr\u003eYear=%{x}\u003cbr\u003eTrade Value (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"import, Actual","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"import, Actual","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[32550690611.0,46524531358.0,57700882616.0,61065465536.0,74473430118.0,129197306224.0,96829162576.0,135663284048.0,177435555736.0,191689471527.0,186628669880.0,178178816605.0,142694804223.0,135652816501.0,156985563722.0,188711350191.0,171275736997.0,141568794630.0,196189979075.0,237447056598.0,221886223535.0,233652364205.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Trade Type=import\u003cbr\u003etype=Predicted\u003cbr\u003eYear=%{x}\u003cbr\u003eTrade Value (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"import, Predicted","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"import, Predicted","orientation":"v","showlegend":true,"x":[2025,2026,2027],"xaxis":"x","y":[247682172364.59097,261482775446.24673,275145372497.08594],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tick ...
